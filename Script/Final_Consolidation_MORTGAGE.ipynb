# %%
import glob
import os
import pandas as pd
import numpy as np
import datetime
import warnings
from maks_lib import output_path
from maks_lib import input_path
warnings.simplefilter(action='ignore')
now = datetime.datetime.now()

extension = 'csv'

# %%
all_files = glob.glob(output_path+'*.{}'.format(extension))
all_mortage_files  = [file for file in all_files if file.split("\\")[-1].startswith("Cons") and "Mortgage" in file.split("\\")[-1]]
all_deposite_files = [file for file in all_files if file.split("\\")[-1].startswith("Cons") and file not in all_mortage_files]

# %%
COLUMN_NAMES = list(pd.read_csv(all_mortage_files[0]).columns)
df_mortgage = pd.DataFrame(columns=COLUMN_NAMES) 
df_deposit = pd.DataFrame(columns=COLUMN_NAMES)

# %%
df_mortgage
# Out:
# Empty DataFrame
# Columns: [Date, Bank_Name, Bank_Product, Bank_Product_Type, Bank_Offer_Feature, Bank_Product_Name, Product_Term, Balance, Product_Interest, Product_Apy, Mortgage_Down_Payment, Mortgage_Loan, Min_Credit_Score_Mortagage, Mortgage_Apr]
# Index: []

# %%
for idx, file in enumerate(all_mortage_files):
    print(file)
    print(pd.read_csv(all_mortage_files[idx]).shape[1])
# Out:
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\pool-master\data\output\Consolidate_BOA_Data_Mortgage03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\pool-master\data\output\Consolidate_PNC_Data_Mortgage_03_09_2018.csv
# 14
# C:\Users\Deepak.BAN-LBMQ24M2\PycharmProjects\pool-master\pool-master\data\output\Consolidate_WellsF_Data_Mortgage_03_09_2018.csv
# 14

# %%
for file in all_mortage_files:
    df_temp =pd.read_csv(file)
    df_temp.columns = ['Date', 'Bank_Name', 'Bank_Product', 'Bank_Product_Type',
       'Bank_Offer_Feature', 'Bank_Product_Name', 'Product_Term', 'Balance',
       'Product_Interest', 'Product_Apy', 'Mortgage_Down_Payment',
       'Mortgage_Loan', 'Min_Credit_Score_Mortagage', 'Mortgage_Apr']
    df_mortgage = pd.concat([df_mortgage, df_temp])

# %%
df_mortgage.shape
# Out:
# (69, 14)

# %%
df_mortgage
# Out:
#         Date                         Bank_Name Bank_Product Bank_Product_Type  \
# 0   3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 1   3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 2   3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 3   3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 4   3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 5   3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 6   3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 7   3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 8   3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 9   3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 10  3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 11  3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 12  3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 13  3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 14  3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 15  3/9/2018              BANK OF AMERICA CORP    Mortgages         Mortgages
# 0   3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 1   3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 2   3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 3   3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 4   3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 5   3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 6   3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 7   3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 8   3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 9   3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 10  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 11  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 12  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 13  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# ..       ...                               ...          ...               ...
# 23  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 24  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 25  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 26  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 27  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 28  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 29  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 30  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 31  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 32  3/9/2018  PNC FINANCIAL SERVICES GROUP INC    Mortgages         Mortgages
# 0   3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 1   3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 2   3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 3   3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 4   3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 5   3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 6   3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 7   3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 8   3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 9   3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 10  3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 11  3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 12  3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 13  3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 14  3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 15  3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 16  3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 17  3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 18  3/9/2018                        Wellsfargo    Mortgages         Mortgages
# 19  3/9/2018                        Wellsfargo    Mortgages         Mortgages
#
#    Bank_Offer_Feature         Bank_Product_Name Product_Term Balance  \
# 0             Offline             30-year fixed           30     NaN
# 1             Offline             20-year fixed           20     NaN
# 2             Offline             15-year fixed           15     NaN
# 3             Offline                  10/1 ARM           30     NaN
# 4             Offline                   7/1 ARM           30     NaN
# 5             Offline                   5/1 ARM           30     NaN
# 6             Offline             30-year fixed           30     NaN
# 7             Offline             20-year fixed           20     NaN
# 8             Offline             15-year fixed           15     NaN
# 9             Offline                  10/1 ARM           30     NaN
# 10            Offline                   7/1 ARM           30     NaN
# 11            Offline                   5/1 ARM           30     NaN
# 12            Offline             30-year fixed           30     NaN
# 13            Offline             15-year fixed           15     NaN
# 14            Offline                   7/1 ARM           30     NaN
# 15            Offline                   5/1 ARM           30     NaN
# 0             Offline               30 Yr Fixed           30     NaN
# 1             Offline               20 Yr Fixed           20     NaN
# 2             Offline               15 Yr Fixed           15     NaN
# 3             Offline               10 Yr Fixed           10     NaN
# 4             Offline                   3-1 ARM           30     NaN
# 5             Offline                   5-1 ARM           30     NaN
# 6             Offline                   7-1 ARM           30     NaN
# 7             Offline                  10-1 ARM           30     NaN
# 8             Offline           FHA 30 YR FIXED           30     NaN
# 9             Offline               FHA 5-1 ARM           30     NaN
# 10            Offline            VA 30 Yr Fixed           30     NaN
# 11            Offline            VA 15 Yr Fixed           15     NaN
# 12            Offline               30 Yr Fixed           30     NaN
# 13            Offline               20 Yr Fixed           20     NaN
# ..                ...                       ...          ...     ...
# 23            Offline            VA 15 Yr Fixed           15     NaN
# 24            Offline   30 YR FIXEDLoan Details           30     NaN
# 25            Offline   15 YR FIXEDLoan Details           15     NaN
# 26            Offline    5-1 YR ARMLoan Details           30     NaN
# 27            Offline    7-1 YR ARMLoan Details           30     NaN
# 28            Offline   10-1 YR ARMLoan Details           30     NaN
# 29            Offline           FHA 30 YR FIXED           30     NaN
# 30            Offline               FHA 5-1 ARM           30     NaN
# 31            Offline            VA 30 YR FIXED           30     NaN
# 32            Offline                VA 5-1 ARM           30     NaN
# 0             Offline        30-Year Fixed Rate           30     NaN
# 1             Offline     30-Year Fixed-Rate VA           30     NaN
# 2             Offline        15-Year Fixed Rate           15     NaN
# 3             Offline                   7/1 ARM           30     NaN
# 4             Offline                   5/1 ARM           30     NaN
# 5             Offline  30-Year Fixed-Rate Jumbo           30     NaN
# 6             Offline  15-Year Fixed-Rate Jumbo           15     NaN
# 7             Offline        20-Year Fixed Rate           20     NaN
# 8             Offline             7/1 ARM Jumbo           30     NaN
# 9             Offline            10/1 ARM Jumbo           30     NaN
# 10            Offline        30-Year Fixed Rate           30     NaN
# 11            Offline        20-Year Fixed Rate           20     NaN
# 12            Offline        15-Year Fixed Rate           15     NaN
# 13            Offline                   5/1 ARM           30     NaN
# 14            Offline  30-Year Fixed-Rate Jumbo           30     NaN
# 15            Offline  15-Year Fixed-Rate Jumbo           15     NaN
# 16            Offline             7/1 ARM Jumbo           30     NaN
# 17            Offline            10/1 ARM Jumbo           30     NaN
# 18            Offline     30-Year Fixed-Rate VA           30     NaN
# 19            Offline                   7/1 ARM           30     NaN
#
#    Product_Interest Product_Apy Mortgage_Down_Payment Mortgage_Loan  \
# 0            4.380%         NaN                   20%     $100,000
# 1            4.250%         NaN                   20%     $100,000
# 2            4.000%         NaN                   20%     $100,000
# 3            4.250%         NaN                   20%     $100,000
# 4            4.000%         NaN                   20%     $100,000
# 5            4.000%         NaN                   20%     $100,000
# 6            4.500%         NaN                   20%     $200,000
# 7            4.250%         NaN                   20%     $200,000
# 8            4.000%         NaN                   20%     $200,000
# 9            4.130%         NaN                   20%     $200,000
# 10           3.880%         NaN                   20%     $200,000
# 11           3.750%         NaN                   20%     $200,000
# 12           4.380%         NaN                   20%     $500,000
# 13           4.130%         NaN                   20%     $500,000
# 14           4.380%         NaN                   20%     $500,000
# 15           4.500%         NaN                   20%     $500,000
# 0             4.63%         NaN                   20%        100000
# 1             4.38%         NaN                   20%        100000
# 2             4.00%         NaN                   20%        100000
# 3             3.75%         NaN                   20%        100000
# 4             3.88%         NaN                   20%        100000
# 5             3.88%         NaN                   20%        100000
# 6             4.13%         NaN                   20%        100000
# 7             4.25%         NaN                   20%        100000
# 8             4.38%         NaN                   20%        500000
# 9             3.75%         NaN                   20%        500000
# 10            4.63%         NaN                   20%        100000
# 11            4.13%         NaN                   20%        100000
# 12            4.38%         NaN                   20%        300000
# 13            4.13%         NaN                   20%        300000
# ..              ...         ...                   ...           ...
# 23            4.00%         NaN                   20%        300000
# 24            4.13%         NaN                   20%        500000
# 25            3.88%         NaN                   20%        500000
# 26            3.13%         NaN                   20%        500000
# 27            3.38%         NaN                   20%        500000
# 28            3.75%         NaN                   20%        500000
# 29            4.38%         NaN                   20%        500000
# 30            3.75%         NaN                   20%        500000
# 31            4.50%         NaN                   20%        500000
# 32            4.00%         NaN                   20%        500000
# 0             4.63%         NaN                25.00%     $200,000
# 1             4.63%         NaN                 0.00%     $200,000
# 2             4.13%         NaN                25.00%     $200,000
# 3             4.25%         NaN                25.00%     $200,000
# 4             4.13%         NaN                25.00%     $200,000
# 5             4.63%         NaN                25.00%     $750,000
# 6             4.38%         NaN                25.00%     $750,000
# 7             4.38%         NaN                25.00%     $200,000
# 8             4.13%         NaN                25.00%     $750,000
# 9             4.25%         NaN                25.00%     $750,000
# 10            4.75%         NaN                25.00%     $200,000
# 11            4.50%         NaN                25.00%     $200,000
# 12            4.25%         NaN                25.00%     $200,000
# 13            4.25%         NaN                25.00%     $200,000
# 14            4.63%         NaN                25.00%     $750,000
# 15            4.50%         NaN                25.00%     $750,000
# 16            4.25%         NaN                25.00%     $750,000
# 17            4.38%         NaN                25.00%     $750,000
# 18            4.63%         NaN                 0.00%     $200,000
# 19            4.38%         NaN                25.00%     $200,000
#
#    Min_Credit_Score_Mortagage Mortgage_Apr
# 0                         740       4.740%
# 1                         740       4.750%
# 2                         740       4.660%
# 3                         740       4.810%
# 4                         740       4.750%
# 5                         740       4.830%
# 6                         740       4.700%
# 7                         740       4.520%
# 8                         740       4.350%
# 9                         740       4.550%
# 10                        740       4.540%
# 11                        740       4.580%
# 12                        740       4.480%
# 13                        740       4.320%
# 14                        740       4.710%
# 15                        740       4.800%
# 0                        720+        4.83%
# 1                        720+        4.65%
# 2                        720+        4.32%
# 3                        720+        4.29%
# 4                        720+        4.62%
# 5                        720+        4.55%
# 6                        720+        4.55%
# 7                        720+        4.58%
# 8                        720+        5.21%
# 9                        720+        5.12%
# 10                       720+        4.97%
# 11                       720+        4.76%
# 12                       720+        4.51%
# 13                       720+        4.32%
# ..                        ...          ...
# 23                       720+        4.49%
# 24                       720+        4.25%
# 25                       720+        4.04%
# 26                       720+        4.42%
# 27                       720+        4.35%
# 28                       720+        4.34%
# 29                       720+        5.21%
# 30                       720+        5.12%
# 31                       720+        4.78%
# 32                       720+        4.55%
# 0                         740        4.68%
# 1                         740        4.94%
# 2                         740        4.26%
# 3                         740        4.58%
# 4                         740        4.59%
# 5                         740        4.63%
# 6                         740        4.39%
# 7                         740        4.49%
# 8                         740        4.46%
# 9                         740        4.46%
# 10                        740        4.78%
# 11                        740        4.55%
# 12                        740        4.32%
# 13                        740        4.60%
# 14                        740        4.64%
# 15                        740        4.51%
# 16                        740        4.51%
# 17                        740        4.52%
# 18                        740        4.92%
# 19                        740        4.60%
#
# [69 rows x 14 columns]

# %%
df_mortgage.dropna(axis=0, how='all', inplace=True)

# %%
df_mortgage.drop(columns=["Product_Apy"], inplace=True)

# %%
df_mortgage.rename(columns={"Balance": "Min_Loan_Amount", "Product_Term": "Term_in_Year","Product_Interest": "Interest","Mortgage_Loan": "Mortgage_Loan_Amt","Min_Credit_Score_Mortagage":"Credit_Score", "Mortgage_Apr":"APR"}, inplace = True,index=str)

# %%
df_mortgage['Date'] = now.strftime("%Y-%m-%d")
df_mortgage['Bank_Native_Country'] = "US"
df_mortgage['State'] = "New York"
df_mortgage['Bank_Local_Currency'] = "USD"
df_mortgage['Bank_Type'] = "Bank"
df_mortgage['Bank_Product'] = "Mortgages"
df_mortgage['Bank_Product_Type'] = "Mortgages"
df_mortgage['Bank_Product_Code'] = np.NAN
df_mortgage['Min_Loan_Amount'] = np.NAN
df_mortgage['Interest_Type'] = "Fixed"
df_mortgage['Mortgage_Category'] = "New Purchase"
df_mortgage['Mortgage_Reason'] = "Primary Residence"
df_mortgage['Mortgage_Pymt_Mode'] = "Principal + Interest"

# %%
df_mortgage.columns
# Out:
# Index(['Date', 'Bank_Name', 'Bank_Product', 'Bank_Product_Type',
#        'Bank_Offer_Feature', 'Bank_Product_Name', 'Term_in_Year',
#        'Min_Loan_Amount', 'Interest', 'Mortgage_Down_Payment',
#        'Mortgage_Loan_Amt', 'Credit_Score', 'APR', 'Bank_Native_Country',
#        'State', 'Bank_Local_Currency', 'Bank_Type', 'Bank_Product_Code',
#        'Interest_Type', 'Mortgage_Category', 'Mortgage_Reason',
#        'Mortgage_Pymt_Mode'],
#       dtype='object')

# %%
arranged_cols = ['Date', 'Bank_Native_Country','State','Bank_Name', 'Bank_Local_Currency','Bank_Type','Bank_Product', 'Bank_Product_Type','Bank_Product_Code','Bank_Product_Name','Min_Loan_Amount','Bank_Offer_Feature','Term_in_Year','Interest_Type','Interest','APR','Mortgage_Loan_Amt','Mortgage_Down_Payment', 'Credit_Score','Mortgage_Category', 'Mortgage_Reason','Mortgage_Pymt_Mode']

# %%
df_mortgage = df_mortgage.reindex(columns= arranged_cols)

# %%
for idx in range(len(df_mortgage.index)):
    if "ARM" in df_mortgage['Bank_Product_Name'].iloc[idx] or "Adjustable Rate" in df_mortgage['Bank_Product_Name'].iloc[idx]:
        df_mortgage['Interest_Type'].iloc[idx] = "Variable"

# %%
for idx in range(len(df_mortgage.index)):
    #print(df_mortgage['Bank_Product_Name'].iloc[idx])
    #print(type(df_mortgage['Bank_Product_Name'].iloc[idx]))
    df_mortgage['Bank_Product_Code'].iloc[idx] = "{0}{1}{2}{3}".format(int(df_mortgage['Term_in_Year'].iloc[idx]),"Y", "M", df_mortgage['Interest_Type'].iloc[idx][0])
    #print(df_mortgage['Interest_Type'].iloc[idx])

# %%
df_mortgage.to_csv(output_path+"US\\" + "US_Mortgage_Data_{}.csv".format(now.strftime("%m_%d_%Y")), index=False )
